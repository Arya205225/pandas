# %%
# datafream
import numpy as np 
import pandas as pd

# %%
#create a datafream 
data = {"Name " : ["aryan","krish","raj ","arpit"],
       "age":[20,25,26,28],
       "city":["lalganj","patna","mujaffarpur","delhi"],
       "salary":[200000,500000,30000,50000]}

# %%
df = pd.DataFrame(data)
df
# Out:
#    Name   age         city  salary
# 0  aryan   20      lalganj  200000
# 1  krish   25        patna  500000
# 2   raj    26  mujaffarpur   30000
# 3  arpit   28        delhi   50000

# %%
# create datafream using list 
my_list = [['aryan',	20,	'lalganj',	200000],
	['krish',	25	,'patna',	500000],
	['raj',	26	,'mujaffarpur',	30000],
	['arpit',	28	,'delhi',	50000]
]
df2 = pd.DataFrame(my_list)
df2
# Out:
#        0   1            2       3
# 0  aryan  20      lalganj  200000
# 1  krish  25        patna  500000
# 2    raj  26  mujaffarpur   30000
# 3  arpit  28        delhi   50000

# %%
col = ["Name","Age","city","salary"]
df2 = pd.DataFrame(my_list,columns=col)
df2
# Out:
#     Name  Age         city  salary
# 0  aryan   20      lalganj  200000
# 1  krish   25        patna  500000
# 2    raj   26  mujaffarpur   30000
# 3  arpit   28        delhi   50000

# %%
# seletion ond indexing of columns
df2
# Out:
#     Name  Age         city  salary
# 0  aryan   20      lalganj  200000
# 1  krish   25        patna  500000
# 2    raj   26  mujaffarpur   30000
# 3  arpit   28        delhi   50000

# %%
df2["Name"]
# Out:
# 0    aryan
# 1    krish
# 2      raj
# 3    arpit
# Name: Name, dtype: object

# %%
df2[["Name","city"]]
# Out:
#     Name         city
# 0  aryan      lalganj
# 1  krish        patna
# 2    raj  mujaffarpur
# 3  arpit        delhi

# %%
# creating new column 
df2["designation"]=["teacher",'doctor',"actor","engineer"]
df2
# Out:
#     Name  Age         city  salary designation
# 0  aryan   20      lalganj  200000     teacher
# 1  krish   25        patna  500000      doctor
# 2    raj   26  mujaffarpur   30000       actor
# 3  arpit   28        delhi   50000    engineer

# %%
# remove a column 
df2.drop("designation",axis=1)
# Out:
#     Name  Age         city  salary
# 0  aryan   20      lalganj  200000
# 1  krish   25        patna  500000
# 2    raj   26  mujaffarpur   30000
# 3  arpit   28        delhi   50000

# %%
# but not proper delete 
df2
# Out:
#     Name  Age         city  salary designation
# 0  aryan   20      lalganj  200000     teacher
# 1  krish   25        patna  500000      doctor
# 2    raj   26  mujaffarpur   30000       actor
# 3  arpit   28        delhi   50000    engineer

# %%
# so i am delete designation 
df2.drop("designation",axis=1,inplace=True)
df2
# Out:
#     Name  Age         city  salary
# 0  aryan   20      lalganj  200000
# 1  krish   25        patna  500000
# 2    raj   26  mujaffarpur   30000
# 3  arpit   28        delhi   50000

# %%
df2
# Out:
#     Name  Age         city  salary
# 0  aryan   20      lalganj  200000
# 1  krish   25        patna  500000
# 2    raj   26  mujaffarpur   30000
# 3  arpit   28        delhi   50000

# %%
# select rows 
df2.loc[0]
# Out:
# Name        aryan
# Age            20
# city      lalganj
# salary     200000
# Name: 0, dtype: object

# %%
df.loc[3]
# Out:
# Name      arpit
# age          28
# city      delhi
# salary    50000
# Name: 3, dtype: object

# %%
# select subset of rows and columns 
df.loc[[0,1]] [["city","salary"]]
# Out:
#       city  salary
# 0  lalganj  200000
# 1    patna  500000

# %%
df.loc[[2,3]] [["city","age"]]
# Out:
#           city  age
# 2  mujaffarpur   26
# 3        delhi   28

# %%
df2
# Out:
#     Name  Age         city  salary
# 0  aryan   20      lalganj  200000
# 1  krish   25        patna  500000
# 2    raj   26  mujaffarpur   30000
# 3  arpit   28        delhi   50000

# %%
# conditional age 

# i only wannt to see those people whose age is above 25
df2[df2["Age"]>25]
# Out:
#     Name  Age         city  salary
# 2    raj   26  mujaffarpur   30000
# 3  arpit   28        delhi   50000

# %%
#  i only want people whose age is above 25 and their city must be delhi 
df2[(df2["Age"]>25)& (df2["city"]=="delhi")]
# Out:
#     Name  Age   city  salary
# 3  arpit   28  delhi   50000
