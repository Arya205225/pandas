# %%
# create pandas series
import numpy as np 
import pandas as pd





labale = ['a','b','c','d']
my_list = [1,2,3,4]
arr = np.array([6,7,8,9])
d = {1:6,2:20,3:30,4:40}

# %%
pd.Series(my_list)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
pd.Series(my_list,index=labale)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    6
# 1    7
# 2    8
# 3    9
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1     6
# 2    20
# 3    30
# 4    40
# dtype: int64
